# %%
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Sat Apr 25 13:57:29 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    25W / 250W |     10MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
S13_PROJECT_PATH = '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/'
sys.path.append(S13_PROJECT_PATH+'/S13_Yolo/')
import os
os.chdir(S13_PROJECT_PATH+'/S13_Yolo/')

# %%
# %cp -av '{S13_PROJECT_PATH}' /content/
# Out:
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom/' -> '/content/S13_Yolo_Custom'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom/YoloV3' -> '/content/S13_Yolo_Custom/YoloV3'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom/YoloV3/train_batch0.png' -> '/content/S13_Yolo_Custom/YoloV3/train_batch0.png'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom/YoloV3/results.txt' -> '/content/S13_Yolo_Custom/YoloV3/results.txt'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom/YoloV3/test_batch0.png' -> '/content/S13_Yolo_Custom/YoloV3/test_batch0.png'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom/YoloV3/test.py' -> '/content/S13_Yolo_Custom/YoloV3/test.py'
# ...

# %%
cd 'S13_Yolo_Custom'
# Out:
# /content/S13_Yolo_Custom

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
# !python YoloV3/train.py --data YoloV3/data/smalcoco/smalcoco.data --batch 3 --cache --cfg YoloV3/cfg/yolov3-spp.cfg --weights weights/yolov3-spp-ultralytics.pt --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='YoloV3/cfg/yolov3-spp.cfg', data='YoloV3/data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-25 11:29:00.791311: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 1749.56it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 100.33it/s]
# ...

# %%
# !python YoloV3/train.py --data data/customdata/custom.data --batch 15 --cache --cfg data/cfg/yolov3-custom.cfg --weights weights/yolov3-spp-ultralytics.pt --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=15, bucket='', cache_images=True, cfg='data/cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-25 14:35:11.490179: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (500 found, 0 missing, 0 empty, 0 duplicate, for 500 images): 100% 500/500 [00:00<00:00, 10483.72it/s]
# Caching images (0.4GB): 100% 500/500 [00:01<00:00, 251.39it/s]
# ...

# %%
# !python YoloV3/detect.py --cfg data/cfg/yolov3-custom.cfg --conf-thres 0.1 --output train_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='data/cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='train_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/501 data/customdata/images/SpongeBob_SquarePants_0.jpg: 512x512 Done. (0.020s)
# image 2/501 data/customdata/images/SpongeBob_SquarePants_1.jpg: 512x512 1 SpongeBobs, Done. (0.020s)
# image 3/501 data/customdata/images/SpongeBob_SquarePants_10.jpg: 512x512 1 SpongeBobs, Done. (0.020s)
# image 4/501 data/customdata/images/SpongeBob_SquarePants_100.jpg: 512x512 1 SpongeBobs, Done. (0.019s)
# ...

# %%
Image(filename='train_out/SpongeBob_SquarePants_55.jpg', width=600)

# %%
Image(filename='train_out/SpongeBob_SquarePants_155.jpg', width=600)

# %%
Image(filename='train_out/SpongeBob_SquarePants_255.jpg', width=600)

# %%
Image(filename='train_out/SpongeBob_SquarePants_355.jpg', width=600)

# %%
Image(filename='train_out/SpongeBob_SquarePants_455.jpg', width=600)

# %%
Image(filename='train_batch0.png', width=500)

# %%
Image(filename='test_batch0.png', width=500)

# %%
# %cp -av '{S13_PROJECT_PATH}'/SpongeBob /content/S13_Yolo_Custom/
# Out:
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//SpongeBob' -> '/content/S13_Yolo_Custom/SpongeBob'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//SpongeBob/Videos' -> '/content/S13_Yolo_Custom/SpongeBob/Videos'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4' -> '/content/S13_Yolo_Custom/SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4'
# '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//SpongeBob/Videos/Spongebob Funny Clipp.mp4' -> '/content/S13_Yolo_Custom/SpongeBob/Videos/Spongebob Funny Clipp.mp4'

# %%
# !python YoloV3/detect.py --cfg data/cfg/yolov3-custom.cfg --conf-thres 0.3 --output "SpongeBob/Detection/" --source "SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='data/cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='SpongeBob/Detection/', save_txt=False, source='SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/955) SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4: 320x512 Done. (0.017s)
# video 1/1 (2/955) SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4: 320x512 Done. (0.016s)
# video 1/1 (3/955) SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4: 320x512 Done. (0.016s)
# video 1/1 (4/955) SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4: 320x512 Done. (0.016s)
# ...

# %%
# !python YoloV3/detect.py --cfg data/cfg/yolov3-custom.cfg --conf-thres 0.3 --output "SpongeBob/Detection/" --source "SpongeBob/Videos/Spongebob Funny Clipp.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='data/cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='SpongeBob/Detection/', save_txt=False, source='SpongeBob/Videos/Spongebob Funny Clipp.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/643) SpongeBob/Videos/Spongebob Funny Clipp.mp4: 320x512 1 SpongeBobs, Done. (0.017s)
# video 1/1 (2/643) SpongeBob/Videos/Spongebob Funny Clipp.mp4: 320x512 1 SpongeBobs, Done. (0.016s)
# video 1/1 (3/643) SpongeBob/Videos/Spongebob Funny Clipp.mp4: 320x512 1 SpongeBobs, Done. (0.017s)
# video 1/1 (4/643) SpongeBob/Videos/Spongebob Funny Clipp.mp4: 320x512 1 SpongeBobs, Done. (0.015s)
# ...

# %%
# %cp -av /content/S13_Yolo_Custom/ '{S13_PROJECT_PATH}'/S13_Yolo/
# Out:
# '/content/S13_Yolo_Custom/' -> '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//S13_Yolo/'
# '/content/S13_Yolo_Custom/YoloV3' -> '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//S13_Yolo/YoloV3'
# '/content/S13_Yolo_Custom/YoloV3/train_batch0.png' -> '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//S13_Yolo/YoloV3/train_batch0.png'
# '/content/S13_Yolo_Custom/YoloV3/results.txt' -> '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//S13_Yolo/YoloV3/results.txt'
# '/content/S13_Yolo_Custom/YoloV3/test_batch0.png' -> '/content/drive/My Drive/Colab Notebooks/Github_Repo/The_School_of_AI/TSAI/TSAI/S13/S13_Yolo_Custom//S13_Yolo/YoloV3/test_batch0.png'
# ...

# %%
# !ffmpeg -i 'SpongeBob/Videos/Spongebob Hindi Intro Theme.mp4' -f mp3 -ab 192000 -vn music
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
# !ffmpeg -i 'SpongeBob/Detection/Spongebob Hindi Intro Theme.mp4' -i music -c:v copy -c:a copy 'SpongeBob/Detection/OUTPUT.mp4'
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
# !ffmpeg -i 'SpongeBob/Videos/Spongebob Funny Clipp.mp4' -f mp3 -ab 192000 -vn music
# !ffmpeg -i 'SpongeBob/Detection/Spongebob Funny Clipp.mp4' -i music -c:v copy -c:a copy 'SpongeBob/Detection/OUTPUT1.mp4'
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...
